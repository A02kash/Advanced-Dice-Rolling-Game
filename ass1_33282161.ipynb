# %% [markdown]
# # Assignment 1
# For this assignment, you will write a Python program that will allow a user (player) to play a dice rolling game. This section specifies the required functionality of the program. <strong>Only a text interface is required for this program</strong>; however, bonus marks will be given if the program would be easy to follow with clear information/error messages for the player.
# The aim of Dice Rolling Game is for a player to roll 2-6 dice multiple times in each game. Victory is achieved when the median value is the same as the mean value in a result list of the dice rolls for all rounds of the game.
# The game starts by letting the player choose a number of dice to play with and also choose the type of dice that they want to use. Player’s roll the dice multiple times, and based on the results, either win or lose. Your task is to write functions to display the main menu, a game menu, as well as other functionalities to check the game history and the win/lose status. Read the following rules and requirements for each function carefully and attempt to implement them.

# %%
"""
Name = Aakash Sharma
Studennt ID = 33282161
Creation Date = 12 - 08 - 2022
Last modified date = 25 - 08 - 2022
Program Description = This program is created to display an interactive user dice roll and check lose or win program
The user will win if the mean and median are the same
and lose if they are not the same

"""
print("\n")

# %%
#for importing random and math libraries import function is used
import random
import math

# %% [markdown]
# # 1. Main menu function

# %%
#this is to derieve the main menu of the program when the user enters their name
def main_menu_function(
    player_name):
    """
       This function is for printing the values inside the main menu function 
       and tell the user what all options he can choose
    
    """
    #if while is true it will print the main menu function
    while(True):
        #This is the main menu which will be shown after a person enters their name
        
        print(r'''
        1. START GAME FUNCTION

        2. GAME HISTORY FUNCTION

        3. EXIT PROGRAM
        ''')

        print("****************************************************")
        #this is to choose which function of the program the user wants to choose
        start_menu = input("Choose one option from 1, 2 or 3: ")
        if start_menu.isdigit():
            start_menu = int(start_menu)
        
            if (start_menu == 1 
                or start_menu ==2 
                or start_menu == 3):
                """if the user chooses one of the 3 options it will return the value and let the user choose 
                options for game menu function """
        
                return start_menu

            else:
                #error if the player enter some other value
                print("****************************************************")
                print(f"Error: {player_name} choose one option from 1,2 or 3")
                print("****************************************************")
                continue
        else:
            #error if the player enter some other value
            print("Sorry enter a number")

# %% [markdown]
# # 2. Game menu function

# %%
#gamemenu function

def game_menu_function():
    """This is the game menu function and it will return what option you want to choose 
        and what function can do what thing """
    while True:
        #these are the options that the function will display and the person have to chosse from one 
        
        print(r'''

            *************************GAME MENU************************

            1)Number of the dice

            2)Type of the dice

            3)Roll the dice

            4)Check if you have won or lost

            5)Exit

            ***********************************************************''')
        #this will store the value of the game_option which is being return in the game
        #option function
        game_option = input("Choose one option: ")
        if game_option.isdigit():
            game_option = int(game_option)
            
            return game_option
        #if the game option that the user chose is not 1,2,3,4 or 5
        #it will go back to the above showing options and show and error
        else: 
            print("****************************************************")
            print("ERROR: Choose something from 1,2,3,4 or 5")
            print("****************************************************")
            continue




def dice_type(
        type_of_dice):
        """In this function the user will select all the different values for the type of the and use 
        one of the type and if the type of the dice is chosen 1 it won't chnage till the user exits 
        first and start a new program"""
        
        while True:
            
            #if type of dice is 0 the function will let you change the value of the type and input some
            #value from 1, 2 or 3
            
            if(type_of_dice == 0):
                print(r'''
                ***************SELECT THE TYPE OF DICE************************
                1) Type 6

                2) Type 8

                3) Type 9
                ***************************************************************''')
                #when the user input some value it will assign type of dice that value
                type_of_dice = int(input("Enter the number of the dice: "))
                print(" ")
                print("***********************************************************")
                print("You will be able to change the type after this roll only....")
                print("***********************************************************")
                print("The number of the dice is: "+ str(num_of_dice))   
                
                #now the system will check if the value is 1 2 or 3 it will assign
                #although if it is not any of the value it will show error
                if type_of_dice not in [1,2,3]:
                        print("**************Invlid input******************")
                        continue
                else:
                    return type_of_dice
                
    
            #if the user wants to change the value of type before the ending of the first round it
            # won't allow the user to do that

            else:
                print("You cant input a value before running")
                break
        # if the user entered type doesnt matches it will return the same value as before  
        return type_of_dice

# %% [markdown]
# # 3. Roll dice function

# %%
def roll_dice_function(
        num_of_dice,
        type_of_dice,
        player_name,
        result_list):
    """this is the function where the dice will generate the values
        and print the dice image for respective values 
        and make a result list and store it in the main list"""
    
    #it will check what is the type of the dice the user have chosen
    if type_of_dice == 1:
        #if the type is six it will generate the n number of values for the type 6 dice 
        #and store it in a list 
        type_six = [1,2,3,4,5,6]
        random_num_list_six = []

        for i in range(0,num_of_dice):
            #now if the range is between 0 to num it will print values
            random_num_six = random.choice(type_six)
            random_num_list_six.append(random_num_six)
            if random_num_six == 1:
                print(r'''
                          ---------
                          |       |
                          |   o   |
                          |       |
                          ---------''')
            
            elif random_num_six == 2:
                print(r'''
                          ---------
                          |       |
                          | o   o |
                          |       |
                          ---------''')
            elif random_num_six == 3:
                print(r'''
                          ---------
                          | o     |
                          |   o   |
                          |     o |
                          ---------''')
            
            elif random_num_six == 4:
                print(r'''
                          ---------
                          | o   o |
                          |       |
                          | o   o |
                          ---------''')
                
            elif random_num_six == 5:
                print(r'''
                          ---------
                          | o   o |
                          |   o   |
                          | o   o |
                          ---------''')
                
            elif random_num_six == 6:
                print(r'''
                          ---------
                          | o   o |
                          | o   o |
                          | o   o |
                          ---------''')
                

        tuple_six = tuple(random_num_list_six)
        print(tuple_six)
        result_list.append(tuple_six)
        

    elif type_of_dice == 2:
        #if the type is eight it will generate the n number of values for the type 8 dice 
        #and store it in a list 
        type_eight = [2,2,3,3,4,8]
        random_num_list_eight = []

        for i in range(0,num_of_dice):
            #now if the range is between 0 to num it will print values
            random_num_eight = random.choice(type_eight)
            random_num_list_eight.append(random_num_eight)
            
            if random_num_eight == 2:
                print(r'''
                          ---------
                          |       |
                          | o   o |
                          |       |
                          ---------''')
            
            elif random_num_eight == 3:
                print(r'''
                          ---------
                          | o     |
                          |   o   |
                          |     o |
                          ---------''')
            
            elif random_num_eight == 4:
                print(r'''
                          ---------
                          | o   o |
                          |       |
                          | o   o |
                          ---------''')
            
            elif random_num_eight == 8:
                print(r'''
                          ---------
                          | o o o |
                          | o   o |
                          | o o o |
                          ---------''')

        tuple_eight = tuple(random_num_list_eight)
        print(tuple_eight) 
        result_list.append(tuple_eight)

    elif type_of_dice == 3:
        #if the type is nine it will generate the n number of values for the type 9 dice 
        #and store it in a list
        type_nine = [1,1,1,1,5,9]
        random_num_list_nine = []

        for i in range(0,num_of_dice):
            #now if the range is between 0 to num it will print values
            random_num_nine = random.choice(type_nine)
            random_num_list_nine.append(random_num_nine)
            
            if random_num_nine == 1:
                print(r'''
                          ---------
                          |       |
                          |   o   |
                          |       |
                          ---------''')
            elif random_num_nine == 5:
                print(r'''
                          ---------
                          | o   o |
                          |   o   |
                          | o   o |
                          ---------''')
                
            elif random_num_nine == 9:
                print(r''' 
                          ---------
                          | o o o |
                          | o o o |
                          | o o o |
                          ---------''')

        tuple_nine = tuple(random_num_list_nine)
        print(tuple_nine)
        result_list.append(tuple_nine)

    else:
        #if the user doesnt choose any of the value it will take user back to the main menu function 
        print("****************************************************")
        print("ERROR: Enter a valid dice number from 1,2 or 3...")
        print("****************************************************")
        main_menu_function(player_name)
        
    
    #if all the requirements are right it will return the list to the main function
    return result_list

# %% [markdown]
# # 4. Check win/lose function

# %%
def check_win_lose(
    result_list):
    """In this function it will display if the user had won or lost"""
    #a temperary variable to store all the values have been created
    temp_res_list = []
    # if the tuple is in the list and the dice value of the created 
    #tuple it will put the value of that tuple inside the list only
    for tup in result_list:
        for dice_values in tup:
            
            temp_res_list.append(dice_values)
    #here the result will be sorted        
    sorted_result = sorted(temp_res_list)
    print(f"The sorted list is: {sorted_result}")
    #then the mean of the list will be calculated
    mean = sum(temp_res_list)/len(temp_res_list)
    print(f"The mean of the results is: {int(mean)}")
    #now to check if the list contains even or odd numbers
    if(len(temp_res_list)%2 == 0):
        
        #if the remainder of the variable after diviing by 2 is 0 then it will be printed  
        middle_value_even = len(temp_res_list)//2
        median_even = (temp_res_list[middle_value_even] + temp_res_list[~middle_value_even])/2
        
        print(f"The median of the result is: {int(median_even)}")
        #if the mean is equal to the mediian the function will return win
        if(mean == median_even):
            print("****************************************************")
            print(f"Congo!! for the {win}")
            print("****************************************************")
            return win
            
        #if the mean is not equal to the mediian the function will return lose
        else:
            print("****************************************************")
            print(f"urgh!! you {lose}")
            print("****************************************************")
            return lose
    
    else:
        #if the function contains odd number of values
        middle_value_odd = len(temp_res_list)//2
        median_odd = temp_res_list[middle_value_odd]
        
        mean_even = sum(temp_res_list)/len(temp_res_list)
        print(f"The mean of the results is: {int(mean)}")
        
        print(f"The median of the result is: {int(median_odd)}")
        #if the mean is equal to the mediian the function will return win
        if(mean == median_odd):
            print("****************************************************")
            print(f"Congo!! for the {win}")
            print("****************************************************")
            return win
        #if the mean is not equal to the mediian the function will return lose
        else:
            print("****************************************************")
            print(f"urgh!! you {lose}")
            print("****************************************************")
            return lose

# %% [markdown]
# # 5. Game history function

# %%
#result is for win or for lose 
res = 0
def game_history_function(
    start_menu,
    result_list,
    res):
    
    # iterate through list of lists 
    game_result_list = []
    
    #to append in the game result list and store in game result list
    for i in result_list:
        game_result_list.append(len(i))
    
    #will return the list and the result
    return game_result_list, res

# %% [markdown]
# # 6. Main function

# %%
player_name = input("Enter player name: ") #this will take playername as input

print("****************************************************")
print(f"Hi! {player_name} welcome to the game...") 
print("****************************************************")

game_history = []

while True:#till while is true the function will run 
    

    start_menu = main_menu_function(player_name)# to browse through the start menu function


    if start_menu == 1: #if the user chooses start game option
        #everything will become 0
        result_list = []
        res = 0
        type_of_dice = 0
        num_of_dice = 0
        win = "win"
        lose = "lose"
        
        while(True):
            
            game_option = game_menu_function()
             #to browse through the game menu option
            
            if game_option == 1:# if the user chooses to enter the number of the dice

                num_of_dice = int(input ("Select the number of dice between 2 to 6: "))
                
                #if the user enters the number of the dice between 2 to 6
                if(num_of_dice >= 2 and num_of_dice <= 6):
                    print("****************************************************")
                    print("The number of the dice is: "+ str(num_of_dice))
                    print("****************************************************")
                    continue
                    
                  
                
                else: #if he enters something other than  digit from 2 - 6 
                    #if the user enters any value other than 2 to 6
                    print("****************************************************")
                    print("Enter a valid dice number... ")
                    print("****************************************************")
                    num_of_dice = 0

                    print("The number of the dice is: "+ str(num_of_dice))
                    game_menu_function()
                    continue
            
            #for entering the type
            elif game_option == 2:

                if num_of_dice >= 2 and num_of_dice <= 6:
                    
                    type_of_dice = dice_type(type_of_dice)

                    print("The type of the dice is: " + str(type_of_dice))
                    
                else:
                    #if the user tries to enter the dice first
                    print("****************************************************")
                    print("Enter the num of the dice first.....")
                    print("****************************************************")
                    continue
                        
                
            elif game_option == 3:#if the user wants to roll the dice and get the results
                if(num_of_dice == 0 and type_of_dice == 0):
                    print("Enter num of dice and type of dice first")
                    print("****************************************************")
                    continue
                    
                else:
                    print("****************************************************")
                    print("Rolling dice")
                    print("****************************************************")
                    result_list = roll_dice_function(num_of_dice,type_of_dice,player_name,result_list)
                    print(result_list)
                    continue
                    
            #if the user wants to check he won or not
            elif game_option == 4:
                if(num_of_dice == 0 and type_of_dice == 0):
                    print("****************************************************")
                    print("ERROR: Enter num of dice and type of dice first")
                    print("****************************************************")
                    continue
                else:
                    print("****************************************************")
                    print("Moment of the truth: Checking have you won or lost")
                    print("****************************************************")
                    res = check_win_lose(result_list)
                    continue
            #if the user wants to exit the program
            elif game_option == 5:
                
                print("****************************************************")
                print("Exiting...")
                print("****************************************************")
                break
                #after break it will go back to the strt game menu
            
            else:
                print("****************************************************")
                print("ERROR: Enter a valid input...")
                print("****************************************************")

    elif start_menu ==2:
        if(res == 0):
            print("****************************************************")
            print("BRO COME ON PLAY THE GAME FIRST...")
            print("****************************************************")
            continue
        #here the game history of the function will be returned
        else:
            #history is used to store the history of all the dice roles
            history = game_history_function(start_menu,result_list,res)
            game_history.append("Dice rolling times: "  + str(len(history[0])) + " Number of Dice: " + str(history[0]) + " Result: " + str(history[1]))
            print(game_history)    
                
    elif start_menu == 3:
        #the user will be ble to exit the program and it will return thnks for playing
        print(f"Thanks {player_name} for playing...")
        break

    else:
        #if the game doesnt give a valid input
        print("****************************************************")
        print("ERROR: Not a valid input...")
        print("****************************************************")
# Out:
# Enter player name: Aakash
# ****************************************************
# Hi! Aakash welcome to the game...
# ****************************************************
#
#         1. START GAME FUNCTION
#
#         2. GAME HISTORY FUNCTION
#
#         3. EXIT PROGRAM
#
# ****************************************************
# Choose one option from 1, 2 or 3: 1
#
#
#             *************************GAME MENU************************
#
#             1)Number of the dice
#
#             2)Type of the dice
#
#             3)Roll the dice
#
#             4)Check if you have won or lost
#
#             5)Exit
#
#             ***********************************************************
# Choose one option: 1
# Select the number of dice between 2 to 6: 3
# ****************************************************
# The number of the dice is: 3
# ****************************************************
#
#
#             *************************GAME MENU************************
#
# ...
